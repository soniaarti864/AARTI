# %% [markdown]
# <a href="https://colab.research.google.com/github/soniaarti864/AARTI/blob/master/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {}
    visited = []
    previous = {}

    for node in graph:
        distances[node] = float('inf')
        previous[node] = None

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None:
            break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous
def get_path(previous, start, end):
    path = []
    current = end

    while current is not None:
        path.insert(0, current)
        current = previous[current]

    if path[0] == start:
        return path
    else:
        return []

# %%
graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 1},
    'E': {'B': 3, 'D': 1, 'F': 6},
    'F': {'C': 8, 'E': 6}
}

distances, previous = dijkstra(graph, 'start')
while True:
    start = input("\nEnter source node: ")

    if start not in graph:
        print("Invalid source node! Try again.")
        continue

    distances, previous = dijkstra(graph, start)

    print("\nShortest Distances:")
    for node in distances:
        print(f"{start} -> {node} = {distances[node]}")

    print("\nShortest Paths:")
    for node in graph:
        path = get_path(previous, start, node)
        if path:
            print(f"{start} -> {node}: {' -> '.join(path)} (Cost: {distances[node]})")
        else:
            print(f"{start} -> {node}: No path")

    choice = input("\nDo you want to try another source node? (y/n): ").lower()
    if choice != 'y':
        break
# Out:
# Enter source node: A
#
# Shortest Distances:
# A -> A = 0
# A -> B = 4
# A -> C = 2
# A -> D = 5
# A -> E = 6
# A -> F = 10
#
# Shortest Paths:
# A -> A: A (Cost: 0)
# A -> B: A -> B (Cost: 4)
# A -> C: A -> C (Cost: 2)
# A -> D: A -> C -> D (Cost: 5)
# A -> E: A -> C -> D -> E (Cost: 6)
# A -> F: A -> C -> F (Cost: 10)
#
# Do you want to try another source node? (y/n): y
#
# Enter source node: E
#
# Shortest Distances:
# E -> A = 6
# E -> B = 3
# E -> C = 4
# E -> D = 1
# E -> E = 0
# E -> F = 6
#
# Shortest Paths:
# E -> A: E -> D -> C -> A (Cost: 6)
# E -> B: E -> B (Cost: 3)
# E -> C: E -> D -> C (Cost: 4)
# E -> D: E -> D (Cost: 1)
# E -> E: E (Cost: 0)
# E -> F: E -> F (Cost: 6)
#
# Do you want to try another source node? (y/n): n

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
